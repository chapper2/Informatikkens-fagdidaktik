# %% [markdown]
# ## Fagdidaktik
#
#
# Parsonspuzzle 1
#
# https://scratch.mit.edu/projects/1271596033
#
# ![image-3.png](attachment:image-3.png)
#
#
# Parsons puzzle 2
#
# https://scratch.mit.edu/projects/1271586731
#
# ![image-2.png](attachment:image-2.png)
#
#
# Parsons puzzle 3
#
# https://scratch.mit.edu/projects/1271582191
#
# ![image.png](attachment:image.png)
#
#
# Parsons puzzle 4
#
# https://scratch.mit.edu/projects/1271600596
#
# ![image-4.png](attachment:image-4.png)
